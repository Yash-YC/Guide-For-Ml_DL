# %%
import PIL
from sklearn.datasets import load_sample_images

# %%
c = load_sample_images().images[0]
f = load_sample_images().images[1]

# %%
f"{c.shape}{f.shape}"
# Out:
# '(427, 640, 3)(427, 640, 3)'

# %%
imc = PIL.Image.fromarray(c)
imc
# Out:
# <PIL.Image.Image image mode=RGB size=640x427 at 0x22EC322EE50>

# %%
imc.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=640x427 at 0x22EC351D8B0>

# %%
c.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# ## Interpolation and Extrapolation
#
# Consider After finding the best fit line for data which can be done throuugh Linear regression and some other algorithms.
#
# - So,Interpolation is process of estimating within a certain known range.The points which are under the certain range is accurate to find inside best fit line and falls under interpolation.
# - extrapolation occurs when we use the data we have to estimate outside the known range.
